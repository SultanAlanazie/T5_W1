# %% [markdown]
# <a href="https://colab.research.google.com/github/SultanAlanazie/T5_W1/blob/main/Task_(1)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('Task (1) Dataset.csv')

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.sample(25)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 1853   16:36:00      Monday              18-30          Male
# 9248   16:40:00     Tuesday              18-30          Male
# 7351   21:12:00   Wednesday            Unknown          Male
# 299    15:40:00      Monday              18-30          Male
# 4109    0:30:00    Saturday              31-50          Male
# 4352   19:20:00   Wednesday            Unknown          Male
# 3857    1:59:00      Monday            Unknown          Male
# 215     7:35:00    Thursday              18-30          Male
# 7806    8:14:00   Wednesday              31-50          Male
# 5651    9:30:00   Wednesday            Unknown          Male
# 1448   15:30:00      Sunday            Over 51          Male
# 1860    8:30:00   Wednesday            Unknown          Male
# 9194   18:15:00    Saturday              31-50          Male
# 7360   18:03:00    Thursday              18-30          Male
# ...

# %%
df = df.drop(columns=['Defect_of_vehicle'],axis=1)
df = df.drop(columns=['Service_year_of_vehicle'],axis=1)
df = df.drop(columns=['Work_of_casuality'],axis=1)
df = df.drop(columns=['Fitness_of_casuality'],axis=1)

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
def clean_data(column):
  return str(column.split()[0])
df['Type_of_vehicle'] = df['Type_of_vehicle'].apply(clean_data)
df['Type_of_vehicle'] = df['Type_of_vehicle'].str.replace('Pick', 'Pickup')
df['Type_of_vehicle'] = df['Type_of_vehicle'].str.replace('Pickupup', 'Pickup')
df['Driving_experience'] = df['Driving_experience'].str.replace('1-2yr','1-5yr')
df['Driving_experience'] = df['Driving_experience'].str.replace('2-5yr','1-5yr')
df['Age_band_of_driver'] = df['Age_band_of_driver'].str.replace('Unknown',df['Age_band_of_driver'].mode()[0])

# %%
df['Type_of_vehicle'].sample(10)
# Out:
# 11677         Other
# 2609     Automobile
# 7529     Automobile
# 1525          Lorry
# 6774           Taxi
# 9108           Taxi
# 11690    Automobile
# 1075     Automobile
# 1637         Public
# 3732     Automobile
# Name: Type_of_vehicle, dtype: object

# %%
df['Driving_experience'].sample(10)
# Out:
# 4941     Above 10yr
# 3218      Below 1yr
# 11861         1-5yr
# 10424         1-5yr
# 7191          1-5yr
# 11926        5-10yr
# 981           1-5yr
# 5575          1-5yr
# 1072         5-10yr
# 81            1-5yr
# Name: Driving_experience, dtype: object

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8439 entries, 1 to 12315
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         8439 non-null   object
#  1   Day_of_week                  8439 non-null   object
#  2   Age_band_of_driver           8439 non-null   object
#  3   Sex_of_driver                8439 non-null   object
#  4   Educational_level            8439 non-null   object
#  5   Vehicle_driver_relation      8439 non-null   object
#  6   Driving_experience           8439 non-null   object
#  7   Type_of_vehicle              8439 non-null   object
#  8   Owner_of_vehicle             8439 non-null   object
#  9   Area_accident_occured        8439 non-null   object
#  10  Lanes_or_Medians             8439 non-null   object
#  11  Road_allignment              8439 non-null   object
#  12  Types_of_Junction            8439 non-null   object
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                  8439.000000           8439.000000
# mean                      2.038038              1.547340
# std                       0.680789              1.014755
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
bar_col= df[['Age_band_of_driver','Type_of_vehicle']]
for column in bar_col:
    plt.figure(figsize=(10, 6))
    df[column].value_counts().plot(kind='pie')
    plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

dftest = df[['Accident_severity','Age_band_of_driver']]
plt.figure(figsize=(8, 6))
sns.countplot(x='Age_band_of_driver', hue='Accident_severity', data=dftest, palette='Set2')
plt.title('')
plt.xlabel('Accident_severity & Age_band_of_driver')
plt.ylabel('Count')
plt.show()

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# Casualty_severity              object
# ...

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
counts = df.groupby('Driving_experience')['Number_of_casualties'].sum()

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=counts.index, autopct='%0.1f%%', startangle=140)
plt.title('Casualties by Driving Experience')
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
df['Number_of_vehicles_involved'].head()
# Out:
# 1    2
# 3    2
# 7    2
# 8    2
# 9    2
# Name: Number_of_vehicles_involved, dtype: int64

# %%
# Aggregate data
total_vehicles = df['Number_of_vehicles_involved'].sum()
total_casualties = df['Number_of_casualties'].sum()

# Data for pie chart
labels = ['Number of Vehicles Involved', 'Number of Casualties']
sizes = [total_vehicles, total_casualties]

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'salmon'])
plt.title('Number of Vehicles Involved and Number of Casualties')

# Show the plo
# Out:
# Text(0.5, 1.0, 'Total Proportions of Number of Vehicles Involved and Number of Casualties')

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
in Casualties by Driving Experience we see that most of the crashes 1-5y experience

in Accident_severity & Age_band_of_driver relation we conclude that highest injury is between 18-30 yr and slightly injured
in Number of Vehicles Involved vs Number of Casualties we conclude vehicles is more than Casualties
